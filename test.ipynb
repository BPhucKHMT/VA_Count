# %%
import torch
print(torch.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import torch
#       2 print(torch.__version__)
#
# ModuleNotFoundError: No module named 'torch'

# %%
import torchvision
print(torchvision.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import torchvision
#       2 print(torchvision.__version__)
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\__init__.py:4
#       1 import os
#       2 import warnings
# ----> 4 import torch
#       5 from torchvision import datasets
#       6 from torchvision import io
#
# ModuleNotFoundError: No module named 'torch'

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.2.6

# %%
import timm 
print(timm.__version__)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import timm
#       2 print(timm.__version__)
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\timm\__init__.py:2
#       1 from .version import __version__ as __version__
# ----> 2 from .layers import (
#       3     is_scriptable as is_scriptable,
#       4     is_exportable as is_exportable,
#       5     set_scriptable as set_scriptable,
#       6     set_exportable as set_exportable,
#       7 )
#       8 from .models import (
#       9     create_model as create_model,
#      10     list_models as list_models,
#    (...)
#      17     get_pretrained_cfg_value as get_pretrained_cfg_value,
#      18 )
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\timm\layers\__init__.py:1
# ----> 1 from ._fx import (
#       2     create_feature_extractor,
#       3     get_graph_node_names,
#       4     register_notrace_function,
#       5     register_notrace_module,
#       6     is_notrace_module,
#       7     is_notrace_function,
#       8     get_notrace_modules,
#       9     get_notrace_functions,
#      10 )
#      11 from .activations import *
#      12 from .adaptive_avgmax_pool import (
#      13     adaptive_avgmax_pool2d,
#      14     select_adaptive_pool2d,
#      15     AdaptiveAvgMaxPool2d,
#      16     SelectAdaptivePool2d,
#      17 )
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\timm\layers\_fx.py:8
#       4 from torch import nn
#       6 try:
#       7     # NOTE we wrap torchvision fns to use timm leaf / no trace definitions
# ----> 8     from torchvision.models.feature_extraction import create_feature_extractor as _create_feature_extractor
#       9     from torchvision.models.feature_extraction import get_graph_node_names as _get_graph_node_names
#      10     has_fx_feature_extraction = True
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\__init__.py:5
#       2 import warnings
#       4 import torch
# ----> 5 from torchvision import datasets
#       6 from torchvision import io
#       7 from torchvision import models
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\datasets\__init__.py:1
# ----> 1 from ._optical_flow import KittiFlow, Sintel, FlyingChairs, FlyingThings3D, HD1K
#       2 from .caltech import Caltech101, Caltech256
#       3 from .celeba import CelebA
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\datasets\_optical_flow.py:12
#       9 import torch
#      10 from PIL import Image
# ---> 12 from ..io.image import _read_png_16
#      13 from .utils import verify_str_arg
#      14 from .vision import VisionDataset
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\io\__init__.py:8
#       5 from ..utils import _log_api_usage_once
#       7 try:
# ----> 8     from ._load_gpu_decoder import _HAS_VIDEO_DECODER
#       9 except ModuleNotFoundError:
#      10     _HAS_VIDEO_DECODER = False
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\io\_load_gpu_decoder.py:1
# ----> 1 from ..extension import _load_library
#       4 try:
#       5     _load_library("Decoder")
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\extension.py:93
#      88             warn("LoadLibraryExW is missing in kernel32.dll")
#      90     torch.ops.load_library(lib_path)
# ---> 93 _check_cuda_version()
#
# File c:\Users\ADMIN\anaconda3\envs\Phuc1\lib\site-packages\torchvision\extension.py:66, in _check_cuda_version()
#      64     t_minor = int(t_version[1])
#      65     if t_major != tv_major or t_minor != tv_minor:
# ---> 66         raise RuntimeError(
#      67             "Detected that PyTorch and torchvision were compiled with different CUDA versions. "
#      68             f"PyTorch has CUDA Version={t_major}.{t_minor} and torchvision has "
#      69             f"CUDA Version={tv_major}.{tv_minor}. "
#      70             "Please reinstall the torchvision that matches your PyTorch install."
#      71         )
#      72 return _version
#
# RuntimeError: Detected that PyTorch and torchvision were compiled with different CUDA versions. PyTorch has CUDA Version=11.5 and torchvision has CUDA Version=11.3. Please reinstall the torchvision that matches your PyTorch install.

# %%
# !pip install --force torchvision==0.12.0+cu115 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torchvision==0.12.0+cu115
#   Downloading https://download.pytorch.org/whl/cu115/torchvision-0.12.0%2Bcu115-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.3 MB ? eta -:--:--
#      --------- ------------------------------ 0.8/3.3 MB 1.3 MB/s eta 0:00:02
#      ------------------- -------------------- 1.6/3.3 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------- - 3.1/3.3 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------- 3.3/3.3 MB 3.6 MB/s  0:00:01
# Collecting typing-extensions (from torchvision==0.12.0+cu115)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting numpy (from torchvision==0.12.0+cu115)
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting requests (from torchvision==0.12.0+cu115)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting torch==1.11.0 (from torchvision==0.12.0+cu115)
#   Using cached https://download.pytorch.org/whl/cu115/torch-1.11.0%2Bcu115-cp310-cp310-win_amd64.whl (2341.5 MB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision==0.12.0+cu115)
#   Using cached pillow-12.0.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests->torchvision==0.12.0+cu115)
#   Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->torchvision==0.12.0+cu115)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->torchvision==0.12.0+cu115)
#   Downloading urllib3-2.6.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->torchvision==0.12.0+cu115)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Using cached pillow-12.0.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp310-cp310-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.0-py3-none-any.whl (131 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: urllib3, typing-extensions, pillow, numpy, idna, charset_normalizer, certifi, torch, requests, torchvision
#
#   Attempting uninstall: urllib3
#
#     Found existing installation: urllib3 2.5.0
#
#     Uninstalling urllib3-2.5.0:
#
#       Successfully uninstalled urllib3-2.5.0
#
#   Attempting uninstall: typing-extensions
#
#     Found existing installation: typing_extensions 4.15.0
#
#     Uninstalling typing_extensions-4.15.0:
#
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#    ---- -----------------------------------  1/10 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    ---- -----------------------------------  1/10 [typing-extensions]
#   Attempting uninstall: pillow
#    ---- -----------------------------------  1/10 [typing-extensions]
#     Found existing installation: pillow 12.0.0
#    ---- -----------------------------------  1/10 [typing-extensions]
#     Uninstalling pillow-12.0.0:
#    ---- -----------------------------------  1/10 [typing-extensions]
#       Successfully uninstalled pillow-12.0.0
#    ---- -----------------------------------  1/10 [typing-extensions]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#    -------- -------------------------------  2/10 [pillow]
#   Attempting uninstall: numpy
#    -------- -------------------------------  2/10 [pillow]
#     Found existing installation: numpy 2.2.6
#    -------- -------------------------------  2/10 [pillow]
#    ------------ ---------------------------  3/10 [numpy]
#     Uninstalling numpy-2.2.6:
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#       Successfully uninstalled numpy-2.2.6
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#   Attempting uninstall: idna
#    ------------ ---------------------------  3/10 [numpy]
#     Found existing installation: idna 3.11
#    ------------ ---------------------------  3/10 [numpy]
#     Uninstalling idna-3.11:
#    ------------ ---------------------------  3/10 [numpy]
#       Successfully uninstalled idna-3.11
#    ------------ ---------------------------  3/10 [numpy]
#   Attempting uninstall: charset_normalizer
#    ------------ ---------------------------  3/10 [numpy]
#    -------------------- -------------------  5/10 [charset_normalizer]
#     Found existing installation: charset-normalizer 3.4.4
#    -------------------- -------------------  5/10 [charset_normalizer]
#     Uninstalling charset-normalizer-3.4.4:
#    -------------------- -------------------  5/10 [charset_normalizer]
#       Successfully uninstalled charset-normalizer-3.4.4
#    -------------------- -------------------  5/10 [charset_normalizer]
#   Attempting uninstall: certifi
#    -------------------- -------------------  5/10 [charset_normalizer]
#     Found existing installation: certifi 2025.11.12
#    -------------------- -------------------  5/10 [charset_normalizer]
#     Uninstalling certifi-2025.11.12:
#    -------------------- -------------------  5/10 [charset_normalizer]
#       Successfully uninstalled certifi-2025.11.12
#    -------------------- -------------------  5/10 [charset_normalizer]
#   Attempting uninstall: torch
#    -------------------- -------------------  5/10 [charset_normalizer]
#     Found existing installation: torch 1.11.0+cu115
#    -------------------- -------------------  5/10 [charset_normalizer]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#     Uninstalling torch-1.11.0+cu115:
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#       Successfully uninstalled torch-1.11.0+cu115
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#    ---------------------------- -----------  7/10 [torch]
#   Attempting uninstall: requests
#    ---------------------------- -----------  7/10 [torch]
#     Found existing installation: requests 2.32.5
#    ---------------------------- -----------  7/10 [torch]
#     Uninstalling requests-2.32.5:
#    ---------------------------- -----------  7/10 [torch]
#       Successfully uninstalled requests-2.32.5
#    ---------------------------- -----------  7/10 [torch]
#   Attempting uninstall: torchvision
#    ---------------------------- -----------  7/10 [torch]
#     Found existing installation: torchvision 0.12.0+cu113
#    ---------------------------- -----------  7/10 [torch]
#     Uninstalling torchvision-0.12.0+cu113:
#    ---------------------------- -----------  7/10 [torch]
#       Successfully uninstalled torchvision-0.12.0+cu113
#    ---------------------------- -----------  7/10 [torch]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ------------------------------------ ---  9/10 [torchvision]
#    ---------------------------------------- 10/10 [torchvision]
#
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 numpy-2.2.6 pillow-12.0.0 requests-2.32.5 torch-1.11.0+cu115 torchvision-0.12.0+cu115 typing-extensions-4.15.0 urllib3-2.6.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADMIN\anaconda3\envs\Phuc1\Lib\site-packages\~=l'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADMIN\anaconda3\envs\Phuc1\Lib\site-packages\~%mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADMIN\anaconda3\envs\Phuc1\Lib\site-packages\~%mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADMIN\anaconda3\envs\Phuc1\Lib\site-packages\~1rch'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADMIN\anaconda3\envs\Phuc1\Lib\site-packages\~-rchvision'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.7.2 requires pyclipper, which is not installed.
# easyocr 1.7.2 requires python-bidi, which is not installed.
# accelerate 1.10.1 requires torch>=2.0.0, but you have torch 1.11.0+cu115 which is incompatible.
# bitsandbytes 0.48.2 requires torch<3,>=2.3, but you have torch 1.11.0+cu115 which is incompatible.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.9.0 which is incompatible.
# kubernetes 34.1.0 requires urllib3<2.4.0,>=1.24.2, but you have urllib3 2.6.0 which is incompatible.
# langchain-huggingface 0.2.0 requires sentence-transformers>=2.6.0, but you have sentence-transformers 2.4.0 which is incompatible.
# langchainhub 0.1.21 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# open-clip-torch 3.2.0 requires torch>=2.0, but you have torch 1.11.0+cu115 which is incompatible.
# peft 0.18.0 requires torch>=1.13.0, but you have torch 1.11.0+cu115 which is incompatible.
# rfdetr 1.2.1 requires torch>=1.13.0, but you have torch 1.11.0+cu115 which is incompatible.
# rfdetr 1.2.1 requires torchvision>=0.14.0, but you have torchvision 0.12.0+cu115 which is incompatible.
# roboflow 1.2.11 requires idna==3.7, but you have idna 3.11 which is incompatible.
# torchaudio 0.12.1 requires torch==1.12.1, but you have torch 1.11.0+cu115 which is incompatible.

# %%
# !pip uninstall torch torchvision torchaudio
# Out:
# ^C

# %%
print("Done")
# Out:
# Done
